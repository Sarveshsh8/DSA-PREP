# %%
prev2 = 0
prev1 = 1

# print(prev2)
# print(prev1)
for fibo in range(3):
    # print(fibo)
    
    newFibo = prev1 + prev2
    print(newFibo)
    prev2 = prev1
    prev1 = newFibo
    print(prev2,prev1)

# %%
print(0)
print(1)
count = 2

def fibonacci(prev1, prev2):
    global count
    if count <= 19:
        newFibo = prev1 + prev2
        # print(newFibo)
        prev2 = prev1
        prev1 = newFibo
        count += 1
        fibonacci(prev1, prev2)
    else:
        return

fibonacci(1,0)

# %%
# def F(n):
#     if n <= 1:
#         return n
#     else:
#         print("value",F(n - 1)+ F(n - 2))
#         return F(n - 1) + F(n - 2)

# print(F(9))

# %%
def sum(n):
    if n==0:
        return 0
    else:
        return n + sum(n-1)

# %%
a = sum(5)
a
# Out:
# 15

# %%
a = [89,56,78,89,98,12]
b = a[0]
for i in a:
    if i < b:
        b = i 


print(b)
# Out:
# 12

# %%
a = [24,56,78,89,43,12,9,100,90,5]

n = len(a)

for i in range(n-1):
    # print("car",a[i])
    for j in range(n-i-1):
        # print("bike",a[j])

        if a[j] > a[j+1]:
            a[j],a[j+1] = a[j+1],a[j]

print(a)
# Out:
# [5, 9, 12, 24, 43, 56, 78, 89, 90, 100]

# %%
class sarvesh:
    height = ""
    weight = 0


sa = sarvesh()

sa.height = 5.8
sa.weight = 65

sa1 = sarvesh()

sa1.height = 5.6
sa1.weight = 70




print(f"{sa.height}, {sa.weight} this sis ")

print(f"{sa1.height}, {sa1.weight} this sis ")
# Out:
# 5.8, 65 this sis
# 5.6, 70 this sis
